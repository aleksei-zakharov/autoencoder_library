# %%
import matplotlib.pyplot as plt

from matplotlib import cm  # to change color scheme

import sys
sys.path.append('../..')  # to go to the main folder of the whole project
from references.global_parameters import MIN_VOL_ON_GRAPHS, MAX_VOL_ON_GRAPHS

vals = [i for i in range(MIN_VOL_ON_GRAPHS, MAX_VOL_ON_GRAPHS + 1)]

plt.scatter(vals, vals, c=vals, s=1, cmap=cm.rainbow)  # s=2 initially
plt.colorbar(location='top')
plt.show()
