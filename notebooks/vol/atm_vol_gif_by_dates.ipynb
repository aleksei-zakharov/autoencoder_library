# %%
import sys
sys.path.append('../..')  # to go to the main folder of the whole project

from src.data.vol.get_atm_vol_surfs_tenors_dates import get_atm_vol_surfs_tenors_dates
data, uniq_opt_tenors, uniq_swap_tenors, dates = get_atm_vol_surfs_tenors_dates()

from src.visualization.vol.gif_surfaces_by_dates import gif_surfaces_by_dates

dates = dates[::7][226:367]  # starting from 2019 to 2022    # [261:295]  for 2022
data = data[::7][226:367]   

gif_surfaces_by_dates(data,
                      dates,
                      x_labels=uniq_swap_tenors,
                      y_labels=uniq_opt_tenors
                      )
