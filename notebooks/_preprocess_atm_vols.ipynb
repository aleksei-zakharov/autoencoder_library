# %% [markdown]
# ### Create ATM vol data from the raw data and save ATM vol data to the file in data folder

# %%
import sys
import matplotlib.pyplot as plt

sys.path.append('..')
from src.data.preprocess_atm_vols import preprocess_atm_vols
preprocess_atm_vols()

# %% [markdown]
# ### Read ATM vol data from the file and plot them

# %%
from src.data.get_atm_vols import get_atm_vols
df = get_atm_vols()
df.plot(title='ATM vol for different option tenor / swap tenor (in basis points)')
# Out:
# <Axes: title={'center': 'ATM vol for different option tenor / swap tenor (in basis points)'}>
