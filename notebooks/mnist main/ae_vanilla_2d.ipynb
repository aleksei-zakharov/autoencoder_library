# %% [markdown]
# ##### Download MNIST images of handwritten digits

# %%
import sys
sys.path.append('../..')  # to go to the main folder of the whole project

# Define the model name
NAME = 'ae_van_mnist_2latd_1000ep_bat100_mse_100_50_25_12'

# Download data
from src.data.mnist.load_mnist_data import load_mnist_data
(x_train, y_train), (x_test, y_test) = load_mnist_data()

# %% [markdown]
# ##### Create and train the model

# %%
# # Create VAE and fit it
# from src.models.ae_vanilla import AeVanilla
# ae = AeVanilla(input_shape=x_train.shape[1:],
#                  hidden_layers_nodes=[100, 50, 25, 12],
#                  latent_space_dim=2,
#                  loss_type='mse'
#                  )
# ae.compile(optimizer='adam')
# history = ae.fit(x_train, 
#                  epochs=1_000, 
#                  batch_size=100,
#                  validation_data=x_test
#                  )

# %% [markdown]
# ##### Save the model

# %%
# from src.utils.save_model_and_history import save_model_and_history
# save_model_and_history(ae, 
#                        history,
#                        NAME,
#                        data_type='mnist')

# %% [markdown]
# ##### Load the model and training history

# %%
from src.utils.load_model_and_history import load_model_and_history
ae, history = load_model_and_history(NAME,
                                     data_type='mnist')
# Out:
# WARNING:tensorflow:From c:\Users\alexi\Documents\All\ETH_UZH\MasterThesis\_MT_Vol_cube\code_my\autoencoder_library\venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:192: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# c:\Users\alexi\Documents\All\ETH_UZH\MasterThesis\_MT_Vol_cube\code_my\autoencoder_library\venv\Lib\site-packages\keras\src\saving\saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 42 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# ##### Plot history of losses

# %%
from src.visualization.plot_history_of_losses import plot_history_of_losses
plot_history_of_losses(history)

# %% [markdown]
# ##### Plot true vs prediction images

# %%
from src.visualization.mnist.plot_true_vs_prediction_images import plot_true_vs_prediction_images
plot_true_vs_prediction_images(ae,
                               x_test,
                               y_test,
                               save_name=NAME)

# %% [markdown]
# ##### Plot 2d latent space values

# %%
from src.visualization.plot_latent_space_2d_values import plot_latent_space_2d_values
plot_latent_space_2d_values(ae, 
                            x_train, 
                            y_train,
                            save_name=NAME,
                            data_type='mnist')

# %% [markdown]
# ##### Predictions from latent space

# %%
from src.visualization.mnist.plot_predictions_from_2d_latent_space import plot_predictions_from_2d_latent_space
plot_predictions_from_2d_latent_space(ae,
                                      n_cols=12,
                                      xmin=-3,
                                      xmax=3,
                                      ymin=-3,
                                      ymax=3,
                                      save_name=NAME
                                      )
